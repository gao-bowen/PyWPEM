# %% [markdown]
# ### 教程地址：`https://github.com/Bin-Cao/PyWPEM`
# ### github 项目地址： `https://github.com/Bin-Cao/PyWPEM`
# ### 软件文档： `https://pyxplore.netlify.app/intro.html`
# ### 项目主页： `https://bin-cao.github.io/PyWPEM`
#
# ### 致谢合作单位：
# + **香港科技大学（广州）**
# + **上海大学**
# + **GreenDynamics**

# %% [markdown]
# # 安装软件

# %% [markdown]
# ## 创建新的 conda 环境
#
# ### 先打开终端（Mac / Linux / Windows Anaconda Prompt）：

# %% [raw]
# conda create -n myenv python=3.10

# %% [markdown]
# + `myenv`：环境名字（可以改成你项目名，比如 xrd-ai）
# + `python=3.10`：建议指定版本

# %% [markdown]
# ## 激活环境
#
# 激活后你会看到前面有 `(myenv)` 标志

# %% [raw]
# conda activate myenv

# %% [markdown]
# ## 安装 Jupyter Notebook

# %% [raw]
# conda install notebook

# %% [markdown]
# ## 安装 PyXplore

# %% [raw]
# pip install PyXplore

# %% [markdown]
# ## 安装 PyXplore 依赖

# %% [raw]
# wget https://raw.githubusercontent.com/Bin-Cao/PyWPEM/main/requirements.txt

# %% [raw]
# python -m pip install -r requirements.txt

# %% [markdown]
# ## 启动 Jupyter Notebook

# %% [raw]
# jupyter notebook

# %% [markdown]
# ## 测试

# %% [raw]
# from PyXplore import WPEM

# %% [markdown]
# ## 查看当前所在的conda 环境

# %% [raw]
# !conda info --envs

# %% [markdown]
# ---

# %% [markdown]
# ## 以后使用软件只需要直接打开环境 打开jupyter 即可直接使用

# %% [raw]
# conda activate myenv

# %% [raw]
# jupyter notebook
