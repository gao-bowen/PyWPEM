# %%
# import PyXplore package
from PyXplore import WPEM
import pandas as pd
# Out:
# WARNING:tensorflow:From /Users/jacob/miniconda3/envs/pywpem/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
#
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software
# Bin Cao, HKUST(Guangzhou), https://bin-cao.github.io
# Paper : https://arxiv.org/abs/2602.16372
# URL : https://github.com/Bin-Cao/PyWPEM
# Executed on : 2026-05-05 14:21:47  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = WPEM.BackgroundFit(intensity_csv, LFctg=0.2, lowAngleRange=20, window_length = 7, bac_num=500)
Var
# Out:
# ================================
# 6.25176894300212

# %%
NaCl, AtomCoordinates,des = WPEM.CIFpreprocess(filepath='NaCl.cif',two_theta_range=(11,110))
# Out:
# the space group of input crystal is : F m -3 m
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 18 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Cubic  |  The initial lattice constants : 5.62 5.62 5.62 90.0 90.0 90.0

# %%
LiCO, AtomCoordinates,des = WPEM.CIFpreprocess(filepath='Li2CO3.cif',two_theta_range=(11,110))
# Out:
# the space group of input crystal is : C 1 2/c 1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 168 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Monoclinic  |  The initial lattice constants : 8.39 5.0 6.21 90.0 114.5 90.0

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [NaCl,LiCO]

# Execute the model
WPEM.XRDfit(
    wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=11 ,low_bound=20,up_bound=50,bta = 0.9,iter_max = 5, asy_C = 0, 
    InitializationEpoch=2, num=7,Ave_Waves=True,)
# Out:
# Started at Tue May  5 14:24:37 2026
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 5.62 5.62 5.62 90.0 90.0 90.0
# The input crystal system is: Monoclinic  |  The initial lattice constants : 8.39 5.0 6.21 90.0 114.5 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                     | 0/5 [00:00<?, ?it/s]WARNING:tensorflow:From /Users/jacob/miniconda3/envs/pywpem/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 1-th iteration
# [array([ 5.62,  5.62,  5.62, 90.  , 90.  , 90.  ]), array([  8.39,   5.  ,   6.21,  90.  , 114.5 ,  90.  ])]
#  20%|█████████                                    | 1/5 [00:10<00:41, 10.31s/it]
# Rp:54.999 | Rwp:94.935 | Rsquare:42.802
# WARNING:tensorflow:From /Users/jacob/miniconda3/envs/pywpem/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 2-th iteration
# [array([ 5.62,  5.62,  5.62, 90.  , 90.  , 90.  ]), array([  8.39,   5.  ,   6.21,  90.  , 114.5 ,  90.  ])]
#  40%|██████████████████                           | 2/5 [00:20<00:31, 10.36s/it]
# Rp:39.763 | Rwp:63.280 | Rsquare:20.700
# WARNING:tensorflow:From /Users/jacob/miniconda3/envs/pywpem/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 3-th iteration
# [array([ 5.63111,  5.63111,  5.63111, 90.     , 90.     , 90.     ]), array([  8.38787,   4.9957 ,   6.19607,  90.     , 114.5    ,  90.     ])]
#  60%|███████████████████████████                  | 3/5 [00:31<00:21, 10.63s/it]
# Rp:34.343 | Rwp:52.516 | Rsquare:7.078
# WARNING:tensorflow:From /Users/jacob/miniconda3/envs/pywpem/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 4-th iteration
# [array([ 5.63276,  5.63276,  5.63276, 90.     , 90.     , 90.     ]), array([  8.38979,   4.99574,   6.19211,  90.     , 114.5    ,  90.     ])]
#  80%|████████████████████████████████████         | 4/5 [00:42<00:10, 10.72s/it]
# Rp:30.963 | Rwp:48.195 | Rsquare:5.660
# WARNING:tensorflow:From /Users/jacob/miniconda3/envs/pywpem/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 5-th iteration
# [array([ 5.63355,  5.63355,  5.63355, 90.     , 90.     , 90.     ]), array([  8.39245,   4.9967 ,   6.18981,  90.     , 114.5    ,  90.     ])]
# 100%|█████████████████████████████████████████████| 5/5 [00:53<00:00, 10.60s/it]
# Rp:29.844 | Rwp:46.788 | Rsquare:5.383
# After update the background :   Rp = 26.246 | Rwp = 44.399 | Rsquare = 5.291
# Mass fraction without structure factor estimate in % : [56.148731708658, 43.851268291342]
#  Saved at the result documents
# 5-th iterations, reach the maximum number of iteration steps.
#  Rp: 26.246
# Rwp: 44.399
#
#
# WPEM program running time :  0 hours 0 minute  57 second
# ('0 hours 0 minute  57 second  ',
#  [array([ 5.63355,  5.63355,  5.63355, 90.     , 90.     , 90.     ]),
#   array([  8.39245,   4.9967 ,   6.18981,  90.     , 114.5    ,  90.     ])])

# %%
WPEM.Plot_Components(lowboundary = 10, name=['NaCl','Li2CO3'], upboundary = 110, wavelength = wavelength, phase = 2)
# Out:
# Name assigned successfully
# Mass fraction estimate in % (calculated by integral area): [44.67551325385305, 55.32448674614696]
#  Saved at the DecomposedComponents document
